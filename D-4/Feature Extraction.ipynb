# %%
from Funcs.Utility import *
import numpy as np
import pandas as pd
from typing import Dict, Callable, Union, Tuple, List, Optional, Iterable, Any
from datetime import timedelta as td
from scipy import stats
import ray
import warnings
import time

# %%
def _safe_na_check(_v):
    _is_nan_inf = False
    
    try:
        _is_nan_inf = np.isnan(_v) or np.isinf(_v)
    except:
        _is_nan_inf = False
    
    return _is_nan_inf or _v is None

# %%
DATA = load(os.path.join(PATH_INTERMEDIATE, 'proc.pkl'))

# %%
DATA
# Out:
# {'CAL': pcode  timestamp
#  P126   2021-12-06 15:40:18.350000+09:00    1.173864
#         2021-12-06 15:40:48.350000+09:00    2.311666
#         2021-12-06 15:41:18.350000+09:00    2.311666
#         2021-12-06 15:41:48.350000+09:00    2.311666
#         2021-12-06 15:42:18.350000+09:00    2.311666
#                                               ...
#  P083   2021-12-28 21:59:26.709000+09:00    0.543229
#         2021-12-28 21:59:56.709000+09:00    0.543229
#         2021-12-28 22:00:26.709000+09:00    0.543229
#         2021-12-28 22:00:56.709000+09:00    0.543229
#         2021-12-28 22:01:00.800000+09:00    0.074078
#  Name: calories, Length: 490040, dtype: float32,
#  'APP_DUR_UNKNOWN': pcode  timestamp
#  P126   2021-12-06 15:37:11.006000+09:00     0.695
#         2021-12-06 15:37:25.888000+09:00    14.881
#         2021-12-06 15:37:26.557000+09:00     0.664
#         2021-12-06 15:37:29.454000+09:00     2.894
#         2021-12-06 15:37:32.659000+09:00     3.172
#                                              ...
#  P083   2021-12-28 23:39:18.838000+09:00     2.837
#         2021-12-28 23:39:20.146000+09:00     1.294
#         2021-12-28 23:45:01.732000+09:00     3.810
#         2021-12-28 23:45:03.252000+09:00     1.495
#         2021-12-28 23:45:08.460000+09:00     5.176
#  Name: duration_sec, Length: 3131000, dtype: float32,
#  'APP_CAT': pcode  timestamp
#  P126   2021-12-06 15:37:10.303000+09:00    UNKNOWN
#         2021-12-06 15:37:10.311000+09:00     SYSTEM
#         2021-12-06 15:37:11.006000+09:00    UNKNOWN
#         2021-12-06 15:37:11.007000+09:00      ENTER
#         2021-12-06 15:37:25.888000+09:00    UNKNOWN
#                                              ...
#  P083   2021-12-28 23:45:01.757000+09:00     SOCIAL
#         2021-12-28 23:45:03.252000+09:00    UNKNOWN
#         2021-12-28 23:45:03.284000+09:00     SYSTEM
#         2021-12-28 23:45:08.460000+09:00    UNKNOWN
#         2021-12-28 23:45:08.498000+09:00      ENTER
#  Name: category, Length: 6350057, dtype: object,
#  'BAT_LEV': pcode  timestamp
#  P126   2021-12-06 15:32:41.971000+09:00     63.0
#         2021-12-06 15:33:21.332000+09:00     63.0
#         2021-12-06 15:33:51.576000+09:00     62.0
#         2021-12-06 15:34:21.775000+09:00     62.0
#         2021-12-06 15:34:52+09:00            62.0
#                                             ...
#  P083   2021-12-28 23:10:01.611000+09:00    100.0
#         2021-12-28 23:19:55.437000+09:00    100.0
#         2021-12-28 23:21:26.431000+09:00    100.0
#         2021-12-28 23:40:00.563000+09:00    100.0
#         2021-12-28 23:43:27.133000+09:00    100.0
#  Name: level, Length: 6574967, dtype: float32,
#  'BAT_STA': pcode  timestamp
#  P126   2021-12-06 15:32:41.971000+09:00    DISCHARGING
#         2021-12-06 15:33:21.332000+09:00    DISCHARGING
#         2021-12-06 15:33:51.576000+09:00    DISCHARGING
#         2021-12-06 15:34:21.775000+09:00    DISCHARGING
#         2021-12-06 15:34:52+09:00           DISCHARGING
#                                                ...
#  P083   2021-12-28 23:10:01.611000+09:00           FULL
#         2021-12-28 23:19:55.437000+09:00           FULL
#         2021-12-28 23:21:26.431000+09:00           FULL
#         2021-12-28 23:40:00.563000+09:00           FULL
#         2021-12-28 23:43:27.133000+09:00           FULL
#  Name: status, Length: 6574967, dtype: object,
#  'BAT_TMP': pcode  timestamp
#  P126   2021-12-06 15:32:41.971000+09:00    26.200001
#         2021-12-06 15:33:21.332000+09:00    25.799999
#         2021-12-06 15:33:51.576000+09:00    26.299999
#         2021-12-06 15:34:21.775000+09:00    26.200001
#         2021-12-06 15:34:52+09:00           26.000000
#                                               ...
#  P083   2021-12-28 23:10:01.611000+09:00    36.799999
#         2021-12-28 23:19:55.437000+09:00    36.200001
#         2021-12-28 23:21:26.431000+09:00    36.299999
#         2021-12-28 23:40:00.563000+09:00    35.200001
#         2021-12-28 23:43:27.133000+09:00    34.099998
#  Name: temperature, Length: 6574967, dtype: float32,
#  'BAT_PLG': pcode  timestamp
#  P126   2021-12-06 15:32:41.971000+09:00    UNDEFINED
#         2021-12-06 15:33:21.332000+09:00    UNDEFINED
#         2021-12-06 15:33:51.576000+09:00    UNDEFINED
#         2021-12-06 15:34:21.775000+09:00    UNDEFINED
#         2021-12-06 15:34:52+09:00           UNDEFINED
#                                               ...
#  P083   2021-12-28 23:10:01.611000+09:00           AC
#         2021-12-28 23:19:55.437000+09:00           AC
#         2021-12-28 23:21:26.431000+09:00           AC
#         2021-12-28 23:40:00.563000+09:00           AC
#         2021-12-28 23:43:27.133000+09:00           AC
#  Name: pluggedType, Length: 6574967, dtype: object,
#  'CALL_DUR': pcode  timestamp
#  P126   2021-12-07 13:30:46.731000+09:00      46.0
#         2021-12-07 14:23:11.189000+09:00     102.0
#         2021-12-07 14:55:42.538000+09:00       3.0
#         2021-12-07 17:17:18.577000+09:00      24.0
#         2021-12-07 18:24:37.078000+09:00      14.0
#                                              ...
#  P083   2021-12-27 22:06:52.702000+09:00    4743.0
#         2021-12-28 08:22:53.319000+09:00     200.0
#         2021-12-28 13:05:08.706000+09:00     194.0
#         2021-12-28 13:38:02.138000+09:00      19.0
#         2021-12-28 22:40:30.293000+09:00     113.0
#  Name: duration, Length: 10065, dtype: float32,
#  'CALL_CNT': pcode  timestamp
#  P126   2021-12-07 13:30:46.731000+09:00    UNKNOWN
#         2021-12-07 14:23:11.189000+09:00     MOBILE
#         2021-12-07 14:55:42.538000+09:00    UNKNOWN
#         2021-12-07 17:17:18.577000+09:00    UNKNOWN
#         2021-12-07 18:24:37.078000+09:00    UNKNOWN
#                                              ...
#  P083   2021-12-27 22:06:52.702000+09:00     MOBILE
#         2021-12-28 08:22:53.319000+09:00     MOBILE
#         2021-12-28 13:05:08.706000+09:00     MOBILE
#         2021-12-28 13:38:02.138000+09:00    UNKNOWN
#         2021-12-28 22:40:30.293000+09:00     MOBILE
#  Name: contactType, Length: 10065, dtype: object,
#  'DATA_RCV': pcode  timestamp
#  P126   2021-12-06 15:32:49.733000+09:00     347010.0
#         2021-12-06 15:33:04.747000+09:00    1096339.0
#         2021-12-06 15:33:19.761000+09:00       6075.0
#         2021-12-06 15:33:34.772000+09:00     660700.0
#         2021-12-06 15:33:49.787000+09:00     458520.0
#                                               ...
#  P083   2021-12-29 00:01:29.415000+09:00     442316.0
#         2021-12-29 00:01:44.439000+09:00      38546.0
#         2021-12-29 00:01:59.452000+09:00      18064.0
#         2021-12-29 00:02:14.463000+09:00      62504.0
#         2021-12-29 00:02:29.494000+09:00     202149.0
#  Name: rxBytes, Length: 10546752, dtype: float32,
#  'DATA_SNT': pcode  timestamp
#  P126   2021-12-06 15:32:49.733000+09:00    31970.0
#         2021-12-06 15:33:04.747000+09:00    18881.0
#         2021-12-06 15:33:19.761000+09:00    17156.0
#         2021-12-06 15:33:34.772000+09:00    15263.0
#         2021-12-06 15:33:49.787000+09:00    24504.0
#                                              ...
#  P083   2021-12-29 00:01:29.415000+09:00    56954.0
#         2021-12-29 00:01:44.439000+09:00    36390.0
#         2021-12-29 00:01:59.452000+09:00     5299.0
#         2021-12-29 00:02:14.463000+09:00    19256.0
#         2021-12-29 00:02:29.494000+09:00    35808.0
#  Name: txBytes, Length: 10546752, dtype: float32,
#  'DATA_MRCV': pcode  timestamp
#  P126   2021-12-06 15:32:49.733000+09:00     347010.0
#         2021-12-06 15:33:04.747000+09:00    1096339.0
#         2021-12-06 15:33:19.761000+09:00       6075.0
#         2021-12-06 15:33:34.772000+09:00     660700.0
#         2021-12-06 15:33:49.787000+09:00     458520.0
#                                               ...
#  P083   2021-12-29 00:01:29.415000+09:00          0.0
#         2021-12-29 00:01:44.439000+09:00          0.0
#         2021-12-29 00:01:59.452000+09:00          0.0
#         2021-12-29 00:02:14.463000+09:00          0.0
#         2021-12-29 00:02:29.494000+09:00          0.0
#  Name: mobileRxBytes, Length: 10546752, dtype: float32,
#  'DATA_MSNT': pcode  timestamp
#  P126   2021-12-06 15:32:49.733000+09:00    31970.0
#         2021-12-06 15:33:04.747000+09:00    18881.0
#         2021-12-06 15:33:19.761000+09:00    17156.0
#         2021-12-06 15:33:34.772000+09:00    15263.0
#         2021-12-06 15:33:49.787000+09:00    24504.0
#                                              ...
#  P083   2021-12-29 00:01:29.415000+09:00        0.0
#         2021-12-29 00:01:44.439000+09:00        0.0
#         2021-12-29 00:01:59.452000+09:00        0.0
#         2021-12-29 00:02:14.463000+09:00        0.0
#         2021-12-29 00:02:29.494000+09:00        0.0
#  Name: mobileTxBytes, Length: 10546752, dtype: float32,
#  'INST_JAC': pcode  timestamp
#  P126   2021-12-06 22:44:43.942000+09:00    1.0
#         2021-12-07 01:48:19.770000+09:00    1.0
#         2021-12-07 04:48:18.340000+09:00    1.0
#         2021-12-07 07:48:18.351000+09:00    1.0
#         2021-12-07 10:48:19.522000+09:00    1.0
#                                            ...
#  P083   2021-12-28 03:39:05.332000+09:00    1.0
#         2021-12-28 06:38:48.427000+09:00    1.0
#         2021-12-28 09:39:00.025000+09:00    1.0
#         2021-12-28 17:05:58.995000+09:00    1.0
#         2021-12-28 20:05:58.928000+09:00    1.0
#  Name: jaccard, Length: 20155, dtype: float32,
#  'LOC_LABEL': pcode  timestamp
#  P126   2021-12-06 15:30:30.622000+09:00    none
#         2021-12-06 15:32:16.025000+09:00    none
#         2021-12-06 15:34:15.170000+09:00    none
#         2021-12-06 15:39:25.419000+09:00    none
#         2021-12-06 15:41:02.878000+09:00    work
#                                             ...
#  P083   2021-12-28 23:33:06.771000+09:00    home
#         2021-12-28 23:39:04.200000+09:00    home
#         2021-12-28 23:45:01.310000+09:00    home
#         2021-12-28 23:45:36.581000+09:00    home
#         2021-12-28 23:51:40.129000+09:00    home
#  Name: label, Length: 612941, dtype: object,
#  'LOC_DST': pcode  timestamp
#  P126   2021-12-06 15:30:30.622000+09:00      0.000000
#         2021-12-06 15:32:16.025000+09:00     75.783302
#         2021-12-06 15:34:15.170000+09:00     78.214386
#         2021-12-06 15:39:25.419000+09:00     16.788128
#         2021-12-06 15:41:02.878000+09:00     13.604548
#                                                ...
#  P083   2021-12-28 23:33:06.771000+09:00      5.711549
#         2021-12-28 23:39:04.200000+09:00      7.898235
#         2021-12-28 23:45:01.310000+09:00      5.523997
#         2021-12-28 23:45:36.581000+09:00      5.960837
#         2021-12-28 23:51:40.129000+09:00    101.850624
#  Name: dist, Length: 612941, dtype: float32,
#  'MSG_SNT': pcode  timestamp
#  P126   2021-12-06 11:46:40+09:00    1.0
#         2021-12-27 15:46:58+09:00    1.0
#         2021-12-31 23:23:11+09:00    1.0
#         2021-12-31 23:24:27+09:00    1.0
#  P041   2021-12-13 13:34:11+09:00    1.0
#                                     ...
#  P083   2021-12-23 12:23:32+09:00    1.0
#         2021-12-23 13:35:49+09:00    1.0
#         2021-12-23 13:38:11+09:00    1.0
#         2021-12-23 13:39:47+09:00    1.0
#         2021-12-23 13:43:40+09:00    1.0
#  Name: event, Length: 1301, dtype: float32,
#  'MSG_RCV': pcode  timestamp
#  P126   2021-12-06 09:58:44.870000+09:00    1.0
#         2021-12-06 11:46:31.697000+09:00    1.0
#         2021-12-06 16:10:22.357000+09:00    1.0
#         2021-12-06 18:53:30+09:00           1.0
#         2021-12-07 09:59:27.209000+09:00    1.0
#                                            ...
#  P083   2021-12-28 09:00:05.116000+09:00    1.0
#         2021-12-28 10:01:07.040000+09:00    1.0
#         2021-12-28 13:25:02.795000+09:00    1.0
#         2021-12-28 14:52:15.291000+09:00    1.0
#         2021-12-28 16:00:47.242000+09:00    1.0
#  Name: event, Length: 20385, dtype: float32,
#  'MSG_ALL': pcode  timestamp
#  P126   2021-12-06 09:58:44.870000+09:00    1.0
#         2021-12-06 11:46:31.697000+09:00    1.0
#         2021-12-06 11:46:40+09:00           1.0
#         2021-12-06 16:10:22.357000+09:00    1.0
#         2021-12-06 18:53:30+09:00           1.0
#                                            ...
#  P083   2021-12-28 09:00:05.116000+09:00    1.0
#         2021-12-28 10:01:07.040000+09:00    1.0
#         2021-12-28 13:25:02.795000+09:00    1.0
#         2021-12-28 14:52:15.291000+09:00    1.0
#         2021-12-28 16:00:47.242000+09:00    1.0
#  Name: event, Length: 21794, dtype: float32,
#  'SCR_EVENT': pcode  timestamp
#  P126   2021-12-06 15:58:42.100000+09:00      SCREEN_OFF
#         2021-12-06 15:58:50.728000+09:00       SCREEN_ON
#         2021-12-06 15:58:51.512000+09:00    USER_PRESENT
#         2021-12-06 16:40:11.306000+09:00      SCREEN_OFF
#         2021-12-06 16:40:13.369000+09:00    USER_PRESENT
#                                                 ...
#  P083   2021-12-28 23:29:20.179000+09:00    USER_PRESENT
#         2021-12-28 23:29:20.312000+09:00       SCREEN_ON
#         2021-12-28 23:39:22.074000+09:00      SCREEN_OFF
#         2021-12-28 23:44:57.020000+09:00       SCREEN_ON
#         2021-12-28 23:44:58.757000+09:00    USER_PRESENT
#  Name: type, Length: 1039528, dtype: object,
#  'SCR_DUR': pcode  timestamp
#  P126   2021-12-06 15:58:51.512000+09:00       0.784000
#         2021-12-06 16:40:11.306000+09:00    2479.793945
#         2021-12-06 16:40:13.369000+09:00       2.063000
#         2021-12-06 16:40:13.935000+09:00       0.566000
#         2021-12-06 17:00:28.891000+09:00    1214.956055
#                                                ...
#  P083   2021-12-28 23:29:20.179000+09:00      10.790000
#         2021-12-28 23:29:20.312000+09:00       0.133000
#         2021-12-28 23:39:22.074000+09:00     601.762024
#         2021-12-28 23:44:57.020000+09:00     334.946014
#         2021-12-28 23:44:58.757000+09:00       1.737000
#  Name: duration_sec, Length: 1037101, dtype: float32,
#  'RING': pcode  timestamp
#  P126   2021-12-10 08:02:58.962000+09:00    VIBRATE
#         2021-12-14 15:20:36.950000+09:00     SILENT
#         2021-12-14 20:24:01.255000+09:00    VIBRATE
#         2021-12-15 15:29:47.495000+09:00     SILENT
#         2021-12-15 17:33:52.764000+09:00    VIBRATE
#                                              ...
#  P083   2021-12-24 20:04:03.720000+09:00     SILENT
#         2021-12-24 20:04:04.207000+09:00     NORMAL
#         2021-12-24 21:11:03.199000+09:00    VIBRATE
#         2021-12-24 22:54:19.721000+09:00     NORMAL
#         2021-12-27 21:39:22.404000+09:00    VIBRATE
#  Name: type, Length: 5548, dtype: object,
#  'CHG': pcode  timestamp
#  P126   2021-12-06 17:01:43.131000+09:00       CONNECTED
#         2021-12-06 23:54:03.009000+09:00    DISCONNECTED
#         2021-12-07 13:39:46.830000+09:00       CONNECTED
#         2021-12-07 13:57:54.501000+09:00    DISCONNECTED
#         2021-12-07 14:06:22.448000+09:00       CONNECTED
#                                                 ...
#  P083   2021-12-28 20:33:14.482000+09:00       CONNECTED
#         2021-12-28 20:56:54.597000+09:00    DISCONNECTED
#         2021-12-28 21:00:23.764000+09:00       CONNECTED
#         2021-12-28 22:23:44.729000+09:00    DISCONNECTED
#         2021-12-28 22:34:12.143000+09:00       CONNECTED
#  Name: type, Length: 51992, dtype: object,
#  'PWR': pcode  timestamp
#  P126   2021-12-09 21:54:40.627000+09:00      ACTIVATED
#         2021-12-10 08:03:11.605000+09:00      ACTIVATED
#         2021-12-10 08:03:59.854000+09:00    DEACTIVATED
#         2021-12-10 13:42:36.444000+09:00      ACTIVATED
#         2021-12-10 13:42:48.263000+09:00    DEACTIVATED
#                                                ...
#  P037   2021-12-20 17:34:38.306000+09:00      ACTIVATED
#         2021-12-20 20:25:40.124000+09:00    DEACTIVATED
#  P022   2021-11-26 19:29:54.881000+09:00      ACTIVATED
#         2021-11-26 20:33:40.456000+09:00      ACTIVATED
#         2021-11-26 21:11:50.543000+09:00    DEACTIVATED
#  Name: type, Length: 798, dtype: object,
#  'BT_BondState': pcode  timestamp
#  P126   2021-12-06 15:31:48.595000+09:00    NONE
#         2021-12-06 15:31:48.596000+09:00    NONE
#         2021-12-06 15:31:52.507000+09:00    NONE
#         2021-12-06 15:31:52.510000+09:00    NONE
#         2021-12-06 15:31:55.739000+09:00    NONE
#                                             ...
#  P083   2021-12-29 00:01:38.716000+09:00    NONE
#         2021-12-29 00:01:39.330000+09:00    NONE
#         2021-12-29 00:01:39.406000+09:00    NONE
#         2021-12-29 00:01:39.737000+09:00    NONE
#         2021-12-29 00:01:41.275000+09:00    NONE
#  Name: bondState, Length: 10443031, dtype: object,
#  'BT_DeviceType': pcode  timestamp
#  P126   2021-12-06 15:31:48.595000+09:00           LE
#         2021-12-06 15:31:48.596000+09:00           LE
#         2021-12-06 15:31:52.507000+09:00           LE
#         2021-12-06 15:31:52.510000+09:00           LE
#         2021-12-06 15:31:55.739000+09:00      CLASSIC
#                                               ...
#  P083   2021-12-29 00:01:38.716000+09:00    UNDEFINED
#         2021-12-29 00:01:39.330000+09:00    UNDEFINED
#         2021-12-29 00:01:39.406000+09:00           LE
#         2021-12-29 00:01:39.737000+09:00           LE
#         2021-12-29 00:01:41.275000+09:00           LE
#  Name: deviceType, Length: 10443031, dtype: object,
#  'BT_classType': pcode  timestamp
#  P126   2021-12-06 15:31:48.595000+09:00      UNDEFINED
#         2021-12-06 15:31:48.596000+09:00      UNDEFINED
#         2021-12-06 15:31:52.507000+09:00      UNDEFINED
#         2021-12-06 15:31:52.510000+09:00      UNDEFINED
#         2021-12-06 15:31:55.739000+09:00    PHONE_SMART
#                                                ...
#  P083   2021-12-29 00:01:38.716000+09:00      UNDEFINED
#         2021-12-29 00:01:39.330000+09:00      UNDEFINED
#         2021-12-29 00:01:39.406000+09:00      UNDEFINED
#         2021-12-29 00:01:39.737000+09:00      UNDEFINED
#         2021-12-29 00:01:41.275000+09:00      UNDEFINED
#  Name: classType, Length: 10443031, dtype: object,
#  'Dozemode': pcode  timestamp
#  P052   2021-11-23 16:54:24.877000+09:00      ACTIVATED
#         2021-11-23 17:01:18.882000+09:00    DEACTIVATED
#         2021-11-23 17:29:22.060000+09:00      ACTIVATED
#         2021-11-23 17:42:25.497000+09:00    DEACTIVATED
#  P050   2021-11-23 17:43:18.184000+09:00      ACTIVATED
#                                                ...
#  P101   2022-01-12 14:56:10.221000+09:00      ACTIVATED
#         2022-01-12 15:12:46.590000+09:00    DEACTIVATED
#         2022-01-12 15:15:26.999000+09:00      ACTIVATED
#         2022-01-12 15:25:52.053000+09:00    DEACTIVATED
#         2022-01-12 15:51:25.145000+09:00      ACTIVATED
#  Name: type, Length: 51183, dtype: object,
#  'Heartrate': pcode  timestamp
#  P126   2021-12-06 15:49:13+09:00    86.0
#         2021-12-06 15:49:23+09:00    85.0
#         2021-12-06 15:49:33+09:00    84.0
#         2021-12-06 15:49:38+09:00    82.0
#         2021-12-06 15:49:43+09:00    81.0
#                                      ...
#  P083   2021-12-28 23:58:31+09:00    95.0
#         2021-12-28 23:58:41+09:00    96.0
#         2021-12-28 23:58:46+09:00    95.0
#         2021-12-28 23:58:51+09:00    96.0
#         2021-12-28 23:58:56+09:00    97.0
#  Name: value, Length: 30018476, dtype: float32,
#  'Notification_VIS': pcode  timestamp
#  P126   2021-12-06 15:39:51.439000+09:00    PRIVATE
#         2021-12-06 15:39:51.855000+09:00    PRIVATE
#         2021-12-06 15:39:52.392000+09:00    PRIVATE
#         2021-12-06 15:39:52.898000+09:00    PRIVATE
#         2021-12-06 15:39:53.471000+09:00    PRIVATE
#                                              ...
#  P083   2021-12-29 00:01:16.317000+09:00    PRIVATE
#         2021-12-29 00:01:31.056000+09:00     SECRET
#         2021-12-29 00:02:26.092000+09:00    PRIVATE
#         2021-12-29 00:02:29.727000+09:00    PRIVATE
#         2021-12-29 00:02:29.857000+09:00     PUBLIC
#  Name: visibility, Length: 16907193, dtype: object,
#  'Notification_CAT': pcode  timestamp
#  P126   2021-12-06 15:39:51.439000+09:00    UNDEFINED
#         2021-12-06 15:39:51.855000+09:00    UNDEFINED
#         2021-12-06 15:39:52.392000+09:00    UNDEFINED
#         2021-12-06 15:39:52.898000+09:00    UNDEFINED
#         2021-12-06 15:39:53.471000+09:00    UNDEFINED
#                                               ...
#  P083   2021-12-29 00:01:16.317000+09:00    UNDEFINED
#         2021-12-29 00:01:31.056000+09:00       STATUS
#         2021-12-29 00:02:26.092000+09:00    UNDEFINED
#         2021-12-29 00:02:29.727000+09:00    UNDEFINED
#         2021-12-29 00:02:29.857000+09:00    UNDEFINED
#  Name: category, Length: 16907193, dtype: object}

# %%
notification_vis_data = DATA['BT_DeviceType']

# Display the first few rows to understand its structure
print(notification_vis_data.head())

# Find all unique feature types in 'Notification_VIS'
unique_feature_types = notification_vis_data.unique()

# Display the unique feature types
print("Unique feature types in 'BT_DeviceType':")
print(unique_feature_types)
# Out:
# pcode  timestamp
# P126   2021-12-06 15:31:48.595000+09:00         LE
#        2021-12-06 15:31:48.596000+09:00         LE
#        2021-12-06 15:31:52.507000+09:00         LE
#        2021-12-06 15:31:52.510000+09:00         LE
#        2021-12-06 15:31:55.739000+09:00    CLASSIC
# Name: deviceType, dtype: object
# Unique feature types in 'BT_DeviceType':
# ['LE' 'CLASSIC' 'UNDEFINED' 'DUAL']

# %% [markdown]
# Extraction functions

# %%
def _extract_numeric_feature(d_key, d_val) -> Dict:
    feature = {}
    
    # Ensure the input is a NumPy array
    v = np.asarray(d_val)
    
    # Check if the data is numeric
    if not np.issubdtype(v.dtype, np.number):
        raise ValueError(f"Input data for {d_key} must be numeric.")
    
    # Handle NaNs and infinities
    if not np.all(np.isfinite(v)):
        raise ValueError(f"Input data for {d_key} contains NaNs or infinities.")
    
    # Calculate histogram
    hist, _ = np.histogram(v, bins='doane', density=False)
    
    # Calculate standard deviation
    std = np.sqrt(np.var(v, ddof=1)) if len(v) > 1 else 0
    
    # Normalize values
    v_norm = (v - np.mean(v)) / std if std != 0 else np.zeros(len(v))
    
    # Populate feature dictionary
    feature[f'{d_key}#AVG'] = np.mean(v) # Sample mean
    feature[f'{d_key}#STD'] = std # Sample standard deviation
    feature[f'{d_key}#SKW'] = stats.skew(v, bias=False) if std != 0 else 0 # Sample skewness
    feature[f'{d_key}#KUR'] = stats.kurtosis(v, bias=False) if std != 0 else 0 # Sample kurtosis
    feature[f'{d_key}#ASC'] = np.sum(np.abs(np.diff(v))) # Abstract sum of changes
    feature[f'{d_key}#BEP'] = stats.entropy(hist) # Binned entropy
    feature[f'{d_key}#MED'] = np.median(v) # Median
    feature[f'{d_key}#TSC'] = np.sqrt(np.sum(np.power(np.diff(v_norm), 2))) # Timeseries complexity
    
    return feature

# %%
def _extract_categorical_feature(cats, d_key, d_val) -> Dict:
    feature = {}
    v = d_val
    cnt = v.value_counts()
    val, sup = cnt.index, cnt.values
    hist = {k: v for k, v in zip(val, sup)}

    # Information Entropy
    feature[f'{d_key}#ETP#'] = stats.entropy(sup / len(v))
    # Abs. Sum of Changes
    feature[f'{d_key}#ASC#'] = np.sum(v.values[1:] != v.values[:-1])
    if len(cats) == 2: # Dichotomous categorical data
        c = cats[0]
        feature[f'{d_key}#RLV_SUP'] = hist[c] / len(v) if c in hist else 0
    else:
        for c in cats:
            feature[f'{d_key}#RLV_SUP={c}'] = hist[c] / len(v)  if c in hist else 0
            
    return feature

# %%
def _extract_timeWindow_feature(is_numeric, cats, d_key, d_val) -> Dict:
    feature = {}
    v = d_val
    if is_numeric:
        feature = _extract_numeric_feature(d_key, v)
    else:
        feature =_extract_categorical_feature(cats, d_key, v)
    return feature

# %%
def _extract_timeWindow_feature(is_numeric, cats, d_key, d_val) -> Dict:
    feature = {}
    v = d_val
    
    if d_key in ['SCR_EVENT']:
        # Extract features specifically for screen events
        s_on = v[v == 'SCREEN_ON'].index
        s_off = v[v == 'SCREEN_OFF'].index
        duration, onset, midpoint = calculate_sleep_duration(s_on, s_off, theta)
        
        if duration:
            feature['Sleep#Duration'] = duration
            onset_hour = onset.hour
            if onset_hour >= 21:
                feature['Sleep#Onset'] = onset_hour - 21
            else:
                feature['Sleep#Onset'] = onset_hour + 3
            feature['Sleep#Midpoint'] = midpoint.hour + midpoint.minute / 60
        else:
            feature['Sleep#Duration'] = 0
            feature['Sleep#Onset'] = 0
            feature['Sleep#Midpoint'] = 0
    else:
        if is_numeric:
            feature = _extract_numeric_feature(d_key, v)
        else:
            feature = _extract_categorical_feature(cats, d_key, v)

    return feature

# %%
#This fucntion is based on the  towards circadian computing: "early to bed and early to rise"
#makes some of us unhealthy and sleep derived
theta=30
def calculate_sleep_duration(s_on, s_off, theta):
    # Merge s_on and s_off into a single DataFrame based on timestamp
    df = pd.merge(pd.DataFrame({'timestamp': s_on, 'event': 'SCREEN_ON'}),
                  pd.DataFrame({'timestamp': s_off, 'event': 'SCREEN_OFF'}),
                  how='outer', on='timestamp')
    # fill missing values in event_x with values from event_y, and vice versa
    df['event_x'] = df['event_x'].fillna(df['event_y'])
    df['event_y'] = df['event_y'].fillna(df['event_x'])
    # drop the event_x and event_y columns
    df = df.drop(columns=['event_y']).rename(columns={'event_x': 'event'})
    # Fill in missing timestamps with NaT and sort by timestamp
    df = df.fillna(pd.NaT).sort_values('timestamp')
    df=df.assign(
         timestamp=lambda x: pd.to_datetime(x['timestamp'], unit='ms', utc=True).dt.tz_convert(DEFAULT_TZ)
     )
    # Filter out screen-on events caused by notifications
    mask = (df['event'] == 'SCREEN_OFF') & ((df['timestamp'].diff().fillna(pd.NaT)  / pd.Timedelta(seconds=1)) > theta)
    filtered_df = df[mask].reset_index(drop=True)
    # Discard non-usage patterns that do not start between 9PM to 7AM (next day)
    sleep_duration = pd.Series(dtype=float)
    sleep_onset = pd.Series(dtype="datetime64[ns]")
    for i in range(len(filtered_df)-1):
        if filtered_df.loc[i, 'timestamp'].hour >= 21 or filtered_df.loc[i, 'timestamp'].hour < 7:
            non_usage_duration = filtered_df.loc[i+1, 'timestamp'] - filtered_df.loc[i, 'timestamp']
            if non_usage_duration.total_seconds() > 0:
                sleep_duration = pd.concat([sleep_duration, pd.Series(non_usage_duration.total_seconds())])
                sleep_onset = pd.concat([sleep_onset , pd.Series(filtered_df.loc[i, 'timestamp'])])
    # Calculate sleep midpoint and apply individual corrective term
    if len(sleep_duration) > 0:
        sleep_duration = sleep_duration.reset_index(drop=True)
        sleep_onset  =sleep_onset.reset_index(drop=True)
        sleep_midpoint = sleep_onset + pd.to_timedelta(sleep_duration/2, unit="s")
        return sleep_duration.max(), sleep_onset.iloc[sleep_duration.idxmax()], sleep_midpoint.iloc[sleep_duration.idxmax()]
    else:
        return None, None, None

# %%
epoch_names = {
    0: 'Dawn',
    1: 'Morning',
    2: 'Afternoon',
    3: 'LateAfternoon',
    4: 'Evening',
    5: 'Night'
}
def _extract(
        pid: str,
        data: Dict[str, pd.Series],
        label: pd.Series,
        label_values: List[str],
#        window_data: Dict[str, Union[int, Callable[[pd.Timestamp], int]]],
#        window_label: Dict[str, Union[int, Callable[[pd.Timestamp], int]]],
        categories: Dict[str, Optional[List[any]]] = None,
        constant_features: Dict[str, any] = None,
        resample_s: Dict[str, float] = None
) -> Tuple[pd.DataFrame, np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    _s = time.time()
    log(f"Begin feature extraction on {pid}'s data.")
    categories = categories or dict()
    constant_features = constant_features or dict()
    resample_s = resample_s or dict()
    X, y, date_times = [], [], []
#    count = 0
    for timestamp in label.index:
        row = dict()
        #Find the start of today and yesterday for extracting today epoch features and yesterday epoch features
        start_of_today = datetime(timestamp.year, timestamp.month, timestamp.day, tzinfo=timestamp.tzinfo)
        start_of_today = pd.Timestamp(start_of_today.date(), tz=DEFAULT_TZ)
        start_of_yesterday = timestamp - pd.Timedelta(days=1)
        start_of_yesterday = pd.Timestamp(start_of_yesterday.date(), tz=DEFAULT_TZ)
        label_cur = label.at[timestamp]
        t = timestamp - td(milliseconds=1)

        #Yesterday and Today 3-hour epochs
        yesterday_time_windows_epoch = []
        for i in range(6):
            start = start_of_yesterday + pd.Timedelta(hours=i*3 + 6 )
            end = start_of_yesterday + pd.Timedelta(hours=(i+1)*3 +6)
            if start <= t:
                yesterday_time_windows_epoch.append((start, min(end, t)))
            else:
                break
        today_time_windows_epoch = []
        for i in range(6):
            start = start_of_today + pd.Timedelta(hours=i*3 +6)
            end = start_of_today + pd.Timedelta(hours=(i+1)*3 + 6)
            if start <= t:
                today_time_windows_epoch.append((start, min(end, t)))
            else:
                break
        
        # Features relevant to participants' info
        for d_key, d_val in constant_features.items():
            row[d_key] = d_val
        # Features from sensor data
        for d_key, d_val in data.items():
            is_numeric = d_key not in categories
            cats = categories.get(d_key) or list()
            d_val = d_val.sort_index()
            # Features relevant to latest value of a given data
            # These features are extracted only for bounded categorical data and numerical data.
            if is_numeric or cats:
                try:
                    v = d_val.loc[:t].iloc[-1]
                except (KeyError, IndexError):
                    v = 0
                if is_numeric:
                    row[f'{d_key}#VAL'] = v
                else:
                    for c in cats:
                        row[f'{d_key}#VAL={c}'] = v == c
            # Features relevant to duration since the latest state change.
            # These features are only for categorical data.
            # In addition, duration since a given state is set recently is considered,
            # that are available only at bounded categorical data.
            if not is_numeric:
                try:
                    v = d_val.loc[:t]
                    row[f'{d_key}#DSC'] = (t - v.index[-1]).total_seconds() if len(v) else -1.0
                    for c in cats:
                        v_sub = v.loc[lambda x: x == c].index
                        row[f'{d_key}#DSC={c}'] = (t - v_sub[-1]).total_seconds() if len(v_sub) else -1.0
                except (KeyError, IndexError):
                    row[f'{d_key}#DSC'] = 0
                    for c in cats:
                        row[f'{d_key}#DSC={c}'] = 0
#             No resampling
            d_val_res =d_val

           # Features extracted from 15-min immediate past time-windows
            w_val = 15 * 60
            try:
                v = d_val_res.loc[t - td(seconds=w_val):t]
            except (KeyError, IndexError):
                continue
            with warnings.catch_warnings():
                warnings.simplefilter('ignore')
                new_row = {f'{k}#ImmediatePast_15': v for k, v in _extract_timeWindow_feature(is_numeric, cats, d_key, v).items()}
                row.update(new_row)

            #############################################################    
            #Features extracted from yesterday epoch time windows
            for count, (start, end) in enumerate(yesterday_time_windows_epoch):
                # Get data for the current yesterday epoch time window
                try:
                    v = d_val_res.loc[start:end]
                except (KeyError, IndexError):
                    continue
                epoch_name = epoch_names.get(count)

                with warnings.catch_warnings():
                    warnings.simplefilter('ignore')
                    new_row = {f'{k}#Yesterday{epoch_name}': v for k, v in _extract_timeWindow_feature(is_numeric, cats, d_key, v).items()}
                    row.update(new_row)
                    
            #Features extracted from today epoch time windows until current time
            for count, (start, end) in enumerate(today_time_windows_epoch):
                # Get data for the current time window
                try:
                    v = d_val_res.loc[start:end]
                except (KeyError, IndexError):
                    continue
                epoch_name = epoch_names.get(count)

                with warnings.catch_warnings():
                    warnings.simplefilter('ignore')
                    new_row = {f'{k}_Today{epoch_name}': v for k, v in _extract_timeWindow_feature(is_numeric, cats, d_key, v).items()}
                    row.update(new_row)
        #Sleep feature extracted from last night's data
        onset_min = start_of_yesterday + pd.Timedelta(hours=21)
        onset_max = start_of_today + pd.Timedelta(hours=14)
        s_on =data['SCR_EVENT'].loc[data['SCR_EVENT']=='ON']
        s_off =data['SCR_EVENT'].loc[data['SCR_EVENT']=='OFF']
        duration, onset, midpoint =calculate_sleep_duration(s_on.loc[onset_min:onset_max].reset_index()['timestamp'], s_off.loc[onset_min:onset_max].reset_index()['timestamp'], theta)
        if duration:
            row['Sleep#Duration'] = duration
            onset_hour = onset.hour
            if onset_hour >=21:
                row['Sleep#Onset'] = onset_hour - 21
            else:
                row['Sleep#Onset'] = onset_hour + 3
        else:
            row['Sleep#Duration'] = 0
            row['Sleep#Onset'] = 0
            
        # Features relevant to time
        day_of_week = ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN'][t.isoweekday() - 1]
        is_weekend = 'Y' if t.isoweekday() > 5 else 'N'
        hour = t.hour

        if 6 <= hour < 9:
            hour_name = 'Dawn'
        elif 9 <= hour < 12:
            hour_name = 'MORNING'
        elif 12 <= hour < 15:
            hour_name = 'AFTERNOON'
        elif 15 <= hour < 18:
            hour_name = 'LATE_AFTERNOON'
        elif 18 <= hour < 21:
            hour_name = 'EVENING'
        elif 21 <= hour < 24:
            hour_name = 'NIGHT'
        else:
            hour_name = 'MIDNIGHT'
            
        for d in ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']:
            row[f'Time#DOW={d}'] = d == day_of_week
        for d in ['Y', 'N']:
            row[f'Time#WKD={d}'] = d == is_weekend
        for d in ['DAWN', 'MORNING', 'AFTERNOON', 'LATE_AFTERNOON', 'EVENING', 'NIGHT', 'MIDNIGHT']:
            row[f'Time#HRN={d}'] = d == hour_name
        

        try:
            last_label = label.loc[label[:t].index.max()]
        except (KeyError, IndexError):
            last_label = 0
        row[f'ESM#LastLabel'] = last_label

#############################################################################################
        #The following code is designed for fixed threshold
        # Label values extracted from yesterday epochs
        for count, (start, end) in enumerate(yesterday_time_windows_epoch):
            try:
                v = label.loc[start:end]
                epoch_name = epoch_names.get(count)
                if len(label_values) <= 2: # Binary classification
                    row[f'ESM#LIK#Yesterday{epoch_name}'] = np.sum(v == label_values[0]) / len(v) if len(v) > 0 else 0
                else:
                    for l in label_values:
                        row[f'ESM#LIK#Yesterday{epoch_name}'] = np.sum(v == l) / len(v) if len(v) > 0 else 0
            except (KeyError, IndexError):
                epoch_name = epoch_names.get(count)
                if len(label_values) <= 2:
                    row[f'ESM#LIK#Yesterday{epoch_name}'] = 0
                else:
                    for l in label_values:
                        row[f'ESM#LIK#Yesterday{epoch_name}'] = 0
        # Label values extracted from today epochs
        for count, (start, end) in enumerate(today_time_windows_epoch):
            try:
                v = label.loc[start:end]
                epoch_name = epoch_names.get(count)
                if len(label_values) <= 2: # Binary classification
                    row[f'ESM#LIK#Today{epoch_name}'] = np.sum(v == label_values[0]) / len(v) if len(v) > 0 else 0
                else:
                    for l in label_values:
                        row[f'ESM#LIK#Today{epoch_name}'] = np.sum(v == l) / len(v) if len(v) > 0 else 0
            except (KeyError, IndexError):
                epoch_name = epoch_names.get(count)
                if len(label_values) <= 2:
                    row[f'ESM#LIK#Today{epoch_name}'] = 0
                else:
                    for l in label_values:
                        row[f'ESM#LIK#Today{epoch_name}'] = 0
        row = {
            k: 0 if _safe_na_check(v) else v
            for k, v in row.items()
        }

        X.append(row)
        y.append(label_cur)
        date_times.append(timestamp)
    
    log(f"Complete feature extraction on {pid}'s data ({time.time() - _s:.2f} s).")
    
    #Without normalization for each user
    X = pd.DataFrame(X)
    
    # Debugging: Inspect X DataFrame and y list
#     print(f"Contents of X DataFrame: {X.head()}")
#     print(f"Shape of X DataFrame: {X.shape}")
#     print(f"Contents of y before conversion: {y}")
#     print(f"Type of y: {type(y)}")
    
    for i, element in enumerate(y):
        print(f"Element {i}: {element}, Type: {type(element)}, Length: {len(element) if hasattr(element, '__len__') else 'N/A'}")
    
    y = np.array([element if not hasattr(element, '__len__') else element[0] for element in y])

#     y = np.asarray(y)
    group = np.repeat(pid, len(y))
    date_times =  np.asarray(date_times)
    
    # Debugging: Verify shapes
#     print(f"Shape of y after conversion: {y.shape}")
#     print(f"Shape of group: {group.shape}")
#     print(f"Shape of date_times: {date_times.shape}")

    return X, y, group, date_times

# %%
def extract(
        pids: Iterable[str],
        data: Dict[str, pd.Series],
        label: pd.Series,
        label_values: List[str],
        categories: Dict[str, Optional[List[Any]]] = None,
        constat_features: Dict[str, Dict[str, Any]] = None,
        resample_s: Dict[str, float] = None,
        with_ray: bool=False
):
    if with_ray and not ray.is_initialized():
        raise EnvironmentError('Ray should be initialized if "with_ray" is set as True.')
    
    func = ray.remote(_extract).remote if with_ray else _extract
    jobs = []
    for pid in pids:
        d = dict()
        for k, v in data.items():
            try:
                d[k] = v.loc[(pid, )]
                if k.startswith('LOC_'):
                    d[k].index = pd.to_datetime(d[k].index, unit='ms', utc=True).tz_convert(DEFAULT_TZ)
                d['SPEED'] = d.pop('LOC_SPEED')
            except (KeyError, IndexError):
                pass
        job = func(
            pid=pid, data=d, label=label.loc[(pid, )],
            label_values=label_values,
            categories=categories,
            constant_features=constat_features[pid],
            resample_s=resample_s
        )
        jobs.append(job)
    
    if with_ray:
        jobs = ray.get(jobs)
    
    # Debugging: Inspect the shapes of the returned elements
#     for i, job in enumerate(jobs):
#         print(f"Job {i}: {[x.shape if hasattr(x, 'shape') else type(x) for x in job]}")
    
    X = pd.concat([x for x, _, _, _ in jobs], axis=0, ignore_index=True)
    y = np.concatenate([x for _, x, _, _ in jobs], axis=0)
    group = np.concatenate([x for _, _, x, _ in jobs], axis=0)
    date_times = np.concatenate([x for _, _, _, x in jobs], axis=0)
    
    # Handle sequences in the DataFrame X
    for column in X.columns:
        if X[column].apply(lambda x: isinstance(x, (list, tuple, np.ndarray))).any():
            X[column] = X[column].apply(lambda x: len(x) if isinstance(x, (list, tuple, np.ndarray)) else x)
    
    t_s = date_times.min().normalize().timestamp()
    t_norm = np.asarray(list(map(lambda x: x.timestamp() - t_s, date_times)))
    C, DTYPE = X.columns, X.dtypes
    
    X = X.fillna({
        **{c: False for c in C[(DTYPE == object) | (DTYPE == bool)]},
        **{c: 0.0 for c in C[(DTYPE != object) & (DTYPE != bool)]},
    }).astype({
        **{c: 'bool' for c in C[(DTYPE == object) | (DTYPE == bool)]},
        **{c: 'float32' for c in C[(DTYPE != object) & (DTYPE != bool)]},
    })
    
    return X, y, group, t_norm, date_times

# %%
import os
import cloudpickle
import pandas as pd

LABEL_VALUES = [1, 0]

RESAMPLE_S = {
    'CAL': 1.0,  # 1 second
    'APP_DUR_UNKNOWN': 1.0,  # 1 second
    'BAT_LEV': 1.0,  # 1 second
    'MSG_RCV': 60.0,  # 1 minute
    'DATA_RCV': 10.0,  # 10 seconds
    'HEARTRATE': 1.0,  # 1 second
}


CATEGORIES = {
    'APP_CAT': ['UNKNOWN' 'SYSTEM' 'ENTER' 'SOCIAL' 'HEALTH' 'WORK' 'INFO'], 
    'BAT_PLG': ['UNDEFINED' 'AC' 'USB' 'WIRELESS'],
    'BAT_STA': ['DISCHARGING' 'CHARGING' 'FULL' 'NOT_CHARGING'],
    'CALL_CNT': ['UNKNOWN' 'MOBILE' 'OTHER' 'WORK' 'HOME' 'UNDEFINED' 'MAIN'],
    'LOC_LABEL': ['none' 'work' 'home'],
    'RING': ['VIBRATE' 'SILENT' 'NORMAL'],
    'CHG': ['DISCONNECTED', 'CONNECTED'],
    'PWR': ['ACTIVATE', 'DEACTIVATE'],
#     'ONOFF': ['SHUTDOWN'],
    'Notification_VIS':['PRIVATE' 'SECRET' 'PUBLIC'],
    'Notification_CAT': ['UNDEFINED' 'STATUS' 'MESSAGE' 'SERVICE' 'PROGRESS' 'SYSTEM' 'REMINDER' 'ALARM' 'TRANSPORT' 'EMAIL' 'CALL' 'EVENT' 'PROMO' 'ERROR' 'RECOMMENDATION' 'SOCIAL' 'NAVIGATION'],
    'Dozemode': ['ACTIVATE', 'DEACTIVATE'],
    'SCR_EVENT':['SCREEN_OFF' 'SCREEN_ON' 'USER_PRESENT'],
    'BT_BondState': ['NONE' 'BONDED' 'BONDING'],
    'BT_DeviceType': ['LE' 'CLASSIC' 'UNDEFINED' 'DUAL'],
    'BT_classType': ['UNDEFINED' 'PHONE_SMART' 'WEARABLE_WRIST_WATCH' 'COMPUTER_LAPTOP'
 'AUDIO_VIDEO_SET_TOP_BOX' 'AUDIO_VIDEO_HANDSFREE'
 'AUDIO_VIDEO_VIDEO_DISPLAY_AND_LOUDSPEAKER'
 'AUDIO_VIDEO_WEARABLE_HEADSET' 'PHONE_CELLULAR' 'COMPUTER_DESKTOP'
 'COMPUTER_HANDHELD_PC_PDA' 'AUDIO_VIDEO_UNCATEGORIZED'
 'AUDIO_VIDEO_LOUDSPEAKER' 'AUDIO_VIDEO_HEADPHONES'
 'AUDIO_VIDEO_HIFI_AUDIO' 'AUDIO_VIDEO_CAR_AUDIO' 'HEALTH_PULSE_OXIMETER'
 'HEALTH_UNCATEGORIZED' 'COMPUTER_UNCATEGORIZED' 'WEARABLE_JACKET'
 'HEALTH_PULSE_RATE' 'AUDIO_VIDEO_PORTABLE_AUDIO' 'PHONE_MODEM_OR_GATEWAY'
 'HEALTH_BLOOD_PRESSURE' 'COMPUTER_WEARABLE' 'HEALTH_DATA_DISPLAY'
 'TOY_ROBOT' 'COMPUTER_PALM_SIZE_PC_PDA' 'COMPUTER_SERVER']

}

# Define the path to the user info file
user_info_file = os.path.join(PATH_INTERMEDIATE,'UserInfo.csv')

# Load the user info data
userinfo = pd.read_csv(user_info_file)

# Process participant information
PINFO = userinfo.set_index('pcode').assign(
    AGE=lambda x: x['age'],
    GEN=lambda x: x['gender'],
    BFI_OPN=lambda x: x['openness'],
    BFI_CON=lambda x: x['conscientiousness'],
    BFI_NEU=lambda x: x['neuroticism'],
    BFI_EXT=lambda x: x['extraversion'],
    BFI_AGR=lambda x: x['agreeableness'],
    GHQ=lambda x: x['GHQ12'],
    PSS=lambda x: x['PSS10'],
    CESD=lambda x: x['CESD-R'],
    SE=lambda x: x['self-efficacy'],
    OPT=lambda x: x['optimism'],
    HOPE=lambda x: x['hope'],
    RES=lambda x: x['resiliency']
)

# Convert the processed info into a dictionary
PINFO = pd.get_dummies(PINFO, prefix_sep='=', dtype=bool).to_dict('index')
PINFO = {k: {f'PIF#{x}': y for x, y in v.items()} for k, v in PINFO.items()}
DATA = load(os.path.join(PATH_INTERMEDIATE, 'proc.pkl'))
LABELS_PROC = pd.read_csv(os.path.join(PATH_INTERMEDIATE, 'labels_1h_esmsyn.csv'), index_col=['pcode','timestamp'],parse_dates=True)

# %%
import warnings
from pandas.errors import PerformanceWarning

warnings.simplefilter(action='ignore', category=PerformanceWarning)
warnings.simplefilter(action="ignore", category=RuntimeWarning)


with on_ray():
# with on_ray():
    #for l in ['valence', 'arousal', 'stress', 'disturbance']:
    for l in ['stress_binary_personal', 'step_count_binary_personal']:
        #In preprocessing, dynamic threshold shows better data balance
        labels = LABELS_PROC[f'{l}']
#         labels = LABELS_PROC['stress_fixed']
        pids = labels.index.get_level_values('pcode').unique()
        feat = extract(
            pids=pids,
            data=DATA,
            label=labels,
            label_values=LABEL_VALUES,
#            window_data=WINDOW_DATA,
#            window_label=WINDOW_LABEL,
            categories=CATEGORIES,
            constat_features=PINFO,
            resample_s=RESAMPLE_S,
            with_ray=True
        )
        dump(feat, os.path.join(PATH_INTERMEDIATE, f'{l}-15min.pkl'))
# Out:
# 2024-07-25 14:42:41,915	INFO worker.py:1612 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (_extract pid=2302962) [24-07-25 14:42:44] Begin feature extraction on P001's data.
# (_extract pid=2302953) [24-07-25 14:42:49] Begin feature extraction on P010's data. [repeated 6x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_extract pid=2302954) [24-07-25 14:42:55] Begin feature extraction on P016's data. [repeated 5x across cluster]
# (_extract pid=2302952) [24-07-25 14:45:07] Complete feature extraction on P014's data (134.59 s).
# (_extract pid=2302955) [24-07-25 14:42:59] Begin feature extraction on P021's data. [repeated 4x across cluster]
# (_extract pid=2302952) Element 0: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 1: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 2: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 3: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 4: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 5: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 6: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 7: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 8: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 9: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 10: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 11: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 12: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 13: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 14: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 15: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 16: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 17: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 18: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 19: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 20: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 21: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 22: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 23: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 24: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 25: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 26: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 27: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 28: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 29: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 30: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 31: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 32: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 33: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 34: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 35: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 36: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 37: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 38: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 39: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 40: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 41: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 42: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 43: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 44: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 45: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 46: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 47: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 48: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 49: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 50: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 51: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 52: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 53: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 54: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 55: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 56: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 57: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 58: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 59: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 60: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 61: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 62: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 63: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 64: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 65: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 66: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 67: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 68: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 69: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 70: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 71: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 72: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 73: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 74: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 75: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 76: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 77: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 78: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 79: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 80: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 81: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 82: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 83: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 84: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 85: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 86: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 87: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 88: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 89: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 90: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 91: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 92: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 93: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 94: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 95: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 96: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 97: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 98: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 99: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 100: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 101: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 102: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 103: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 104: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 105: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 106: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 107: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 108: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 109: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 110: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 111: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 112: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 113: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 114: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 115: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 116: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 117: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 118: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 119: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 120: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 121: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 122: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 123: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 124: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 125: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 126: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 127: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 128: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 129: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 130: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 131: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 132: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 133: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 134: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 135: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 136: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 137: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 138: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 139: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 140: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 141: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 142: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 143: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 144: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 145: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 146: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 147: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 148: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 149: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 150: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 151: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 152: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 153: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 154: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 155: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 156: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 157: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 158: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 159: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 160: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 161: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 162: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 163: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 164: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 165: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 166: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 167: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 168: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 169: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 170: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 171: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 172: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 173: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 174: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 175: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 176: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302952) Element 177: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) [24-07-25 14:45:16] Complete feature extraction on P001's data (152.47 s).
# (_extract pid=2302952) [24-07-25 14:45:07] Begin feature extraction on P022's data.
# (_extract pid=2302962) Element 0: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 1: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 2: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 3: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 4: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 5: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 6: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 7: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 8: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 9: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 10: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 11: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 12: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 13: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 14: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 15: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 16: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 17: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 18: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 19: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 20: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 21: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 22: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 23: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 24: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 25: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 26: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 27: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 28: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 29: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 30: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 31: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 32: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 33: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 34: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 35: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 36: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 37: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 38: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 39: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 40: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 41: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 42: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 43: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 44: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 45: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 46: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 47: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 48: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 49: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 50: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 51: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 52: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 53: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 54: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 55: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 56: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 57: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 58: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 59: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 60: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 61: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 62: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 63: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 64: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 65: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 66: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 67: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 68: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 69: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 70: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 71: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 72: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 73: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 74: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 75: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 76: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 77: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 78: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 79: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 80: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 81: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 82: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 83: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 84: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 85: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 86: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 87: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 88: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 89: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 90: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 91: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 92: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 93: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 94: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 95: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 96: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 97: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 98: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 99: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 100: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 101: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 102: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 103: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 104: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 105: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 106: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 107: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 108: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 109: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 110: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 111: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 112: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 113: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 114: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 115: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 116: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 117: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 118: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 119: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 120: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 121: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 122: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 123: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 124: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 125: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 126: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 127: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 128: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 129: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 130: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 131: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 132: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 133: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 134: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 135: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 136: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 137: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 138: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 139: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 140: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 141: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 142: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 143: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 144: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 145: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 146: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 147: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 148: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 149: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 150: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 151: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 152: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 153: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 154: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 155: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 156: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 157: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 158: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 159: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 160: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 161: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 162: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 163: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 164: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 165: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 166: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 167: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 168: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 169: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 170: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 171: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 172: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 173: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 174: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 175: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 176: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 177: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 178: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 179: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 180: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 181: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 182: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 183: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 184: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 185: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 186: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 187: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 188: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 189: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 190: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 191: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 192: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 193: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 194: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) Element 195: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302962) [24-07-25 14:45:17] Begin feature extraction on P023's data.
# (_extract pid=2302953) [24-07-25 14:45:22] Complete feature extraction on P010's data (152.72 s).
# (_extract pid=2302953) Element 195: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 196x across cluster]
# (_extract pid=2302953) [24-07-25 14:45:22] Begin feature extraction on P024's data.
# (_extract pid=2302957) [24-07-25 14:45:27] Complete feature extraction on P009's data (158.79 s).
# (_extract pid=2302957) Element 196: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 197x across cluster]
# (_extract pid=2302965) [24-07-25 14:45:27] Complete feature extraction on P008's data (160.19 s).
# (_extract pid=2302957) [24-07-25 14:45:27] Begin feature extraction on P025's data.
# (_extract pid=2302951) Element 196: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 590x across cluster]
# (_extract pid=2302951) [24-07-25 14:45:32] Complete feature extraction on P007's data (165.77 s). [repeated 2x across cluster]
# (_extract pid=2302951) [24-07-25 14:45:32] Begin feature extraction on P028's data. [repeated 3x across cluster]
# (_extract pid=2302956) [24-07-25 14:45:40] Complete feature extraction on P019's data (163.12 s).
# (_extract pid=2302956) Element 0: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 1: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 2: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 3: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 4: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 5: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 6: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 7: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 8: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 9: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 10: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 11: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 12: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 13: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 14: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 15: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 16: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 17: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 18: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 19: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 20: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 21: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 22: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 23: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 24: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 25: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 26: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 27: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 28: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 29: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 30: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 31: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 32: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 33: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 34: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 35: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 36: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 37: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 38: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 39: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 40: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 41: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 42: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 43: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 44: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 45: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 46: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 47: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 48: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 49: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 50: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 51: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 52: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 53: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 54: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 55: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 56: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 57: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 58: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 59: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 60: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 61: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 62: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 63: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 64: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 65: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 66: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 67: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 68: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 69: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 70: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 71: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 72: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 73: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 74: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 75: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 76: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 77: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 78: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 79: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 80: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 81: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 82: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 83: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 84: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 85: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 86: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 87: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 88: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 89: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 90: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 91: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 92: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 93: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 94: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 95: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 96: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 97: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 98: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 99: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 100: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 101: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 102: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 103: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 104: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 105: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 106: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 107: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 108: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 109: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 110: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 111: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 112: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 113: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 114: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 115: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 116: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 117: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 118: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 119: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 120: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 121: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 122: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 123: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 124: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 125: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 126: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 127: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 128: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 129: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 130: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 131: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 132: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 133: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 134: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 135: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 136: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 137: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 138: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 139: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 140: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 141: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 142: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 143: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 144: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 145: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 146: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 147: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 148: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 149: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 150: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 151: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 152: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 153: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 154: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 155: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 156: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 157: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 158: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 159: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 160: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 161: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 162: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 163: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 164: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 165: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 166: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 167: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 168: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 169: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 170: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 171: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 172: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 173: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 174: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 175: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 176: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 177: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 178: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 179: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 180: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 181: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 182: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 183: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 184: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 185: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 186: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 187: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 188: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 189: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 190: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 191: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 192: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 193: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 194: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 195: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 196: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 197: 0, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 198: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) Element 199: 1, Type: <class 'numpy.int64'>, Length: N/A
# (_extract pid=2302956) [24-07-25 14:45:41] Begin feature extraction on P029's data.
# ...
# (_extract pid=2302956) [24-07-25 15:06:51] Begin feature extraction on P049's data. [repeated 2x across cluster]
# (_extract pid=2302953) [24-07-25 15:07:03] Complete feature extraction on P029's data (150.03 s). [repeated 2x across cluster]
# (_extract pid=2302953) Element 202: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 203x across cluster]
# (_extract pid=2302953) [24-07-25 15:07:03] Begin feature extraction on P050's data.
# (_extract pid=2302965) [24-07-25 15:07:10] Complete feature extraction on P034's data (150.38 s).
# (_extract pid=2302965) [24-07-25 15:07:10] Begin feature extraction on P051's data.
# (_extract pid=2302952) [24-07-25 15:07:19] Complete feature extraction on P033's data (161.05 s).
# (_extract pid=2302965) Element 204: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 205x across cluster]
# (_extract pid=2302952) [24-07-25 15:07:20] Begin feature extraction on P052's data.
# (_extract pid=2302951) [24-07-25 15:07:25] Complete feature extraction on P030's data (168.71 s). [repeated 2x across cluster]
# (_extract pid=2302966) Element 180: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 383x across cluster]
# (_extract pid=2302966) [24-07-25 15:07:24] Begin feature extraction on P054's data.
# (_extract pid=2302951) [24-07-25 15:07:26] Begin feature extraction on P055's data.
# (_extract pid=2302960) [24-07-25 15:08:53] Complete feature extraction on P042's data (138.42 s). [repeated 3x across cluster]
# (_extract pid=2302957) Element 225: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 665x across cluster]
# (_extract pid=2302957) [24-07-25 15:07:28] Begin feature extraction on P057's data. [repeated 2x across cluster]
# (_extract pid=2302961) [24-07-25 15:09:01] Complete feature extraction on P046's data (134.48 s). [repeated 2x across cluster]
# (_extract pid=2302956) Element 196: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 383x across cluster]
# (_extract pid=2302956) [24-07-25 15:08:54] Begin feature extraction on P059's data. [repeated 2x across cluster]
# (_extract pid=2302958) [24-07-25 15:09:23] Complete feature extraction on P045's data (158.75 s). [repeated 4x across cluster]
# (_extract pid=2302964) Element 181: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 776x across cluster]
# (_extract pid=2302964) [24-07-25 15:09:06] Begin feature extraction on P066's data. [repeated 4x across cluster]
# (_extract pid=2302965) [24-07-25 15:09:36] Complete feature extraction on P051's data (146.30 s).
# (_extract pid=2302958) Element 209: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 210x across cluster]
# (_extract pid=2302958) [24-07-25 15:09:24] Begin feature extraction on P067's data.
# (_extract pid=2302953) [24-07-25 15:09:36] Complete feature extraction on P050's data (153.41 s).
# (_extract pid=2302965) [24-07-25 15:09:37] Begin feature extraction on P069's data.
# (_extract pid=2302962) Element 236: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 853x across cluster]
# (_extract pid=2302966) [24-07-25 15:09:43] Complete feature extraction on P054's data (139.05 s). [repeated 3x across cluster]
# (_extract pid=2302962) [24-07-25 15:09:39] Begin feature extraction on P072's data. [repeated 3x across cluster]
# (_extract pid=2302951) Element 187: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 572x across cluster]
# (_extract pid=2302952) [24-07-25 15:10:00] Complete feature extraction on P052's data (160.19 s). [repeated 3x across cluster]
# (_extract pid=2302951) [24-07-25 15:09:44] Begin feature extraction on P075's data. [repeated 3x across cluster]
# (_extract pid=2302952) Element 205: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 206x across cluster]
# (_extract pid=2302957) [24-07-25 15:10:42] Complete feature extraction on P057's data (194.36 s).
# (_extract pid=2302952) [24-07-25 15:10:01] Begin feature extraction on P076's data.
# (_extract pid=2302957) [24-07-25 15:10:43] Begin feature extraction on P077's data.
# (_extract pid=2302956) [24-07-25 15:10:53] Complete feature extraction on P059's data (119.05 s).
# (_extract pid=2302957) Element 256: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 257x across cluster]
# (_extract pid=2302956) [24-07-25 15:10:54] Begin feature extraction on P078's data.
# (_extract pid=2302960) [24-07-25 15:11:10] Complete feature extraction on P058's data (136.64 s).
# (_extract pid=2302956) Element 190: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 191x across cluster]
# (_extract pid=2302960) [24-07-25 15:11:11] Begin feature extraction on P079's data.
# (_extract pid=2302954) [24-07-25 15:11:40] Complete feature extraction on P065's data (154.60 s).
# (_extract pid=2302960) Element 180: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 181x across cluster]
# (_extract pid=2302954) [24-07-25 15:11:40] Begin feature extraction on P081's data.
# (_extract pid=2302955) [24-07-25 15:11:48] Complete feature extraction on P064's data (163.87 s).
# (_extract pid=2302954) Element 197: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 198x across cluster]
# (_extract pid=2302955) [24-07-25 15:11:48] Begin feature extraction on P083's data.
# (_extract pid=2302964) [24-07-25 15:11:50] Complete feature extraction on P066's data (164.23 s).
# (_extract pid=2302964) Element 224: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 433x across cluster]
# (_extract pid=2302964) [24-07-25 15:11:50] Begin feature extraction on P084's data.
# (_extract pid=2302962) [24-07-25 15:11:57] Complete feature extraction on P072's data (137.84 s).
# (_extract pid=2302962) [24-07-25 15:11:58] Begin feature extraction on P086's data.
# (_extract pid=2302961) [24-07-25 15:12:01] Complete feature extraction on P061's data (179.35 s).
# (_extract pid=2302959) Element 186: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 599x across cluster]
# (_extract pid=2302959) [24-07-25 15:12:02] Begin feature extraction on P088's data. [repeated 2x across cluster]
# (_extract pid=2302958) [24-07-25 15:12:18] Complete feature extraction on P067's data (174.41 s). [repeated 3x across cluster]
# (_extract pid=2302963) Element 195: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 196x across cluster]
# (_extract pid=2302963) [24-07-25 15:12:05] Begin feature extraction on P090's data.
# (_extract pid=2302958) [24-07-25 15:12:18] Begin feature extraction on P091's data.
# (_extract pid=2302952) [24-07-25 15:12:24] Complete feature extraction on P076's data (143.52 s). [repeated 2x across cluster]
# (_extract pid=2302953) Element 213: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 446x across cluster]
# (_extract pid=2302953) [24-07-25 15:12:22] Begin feature extraction on P092's data.
# (_extract pid=2302952) [24-07-25 15:12:25] Begin feature extraction on P094's data.
# (_extract pid=2302965) [24-07-25 15:12:50] Complete feature extraction on P069's data (193.54 s). [repeated 2x across cluster]
# (_extract pid=2302951) Element 216: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 418x across cluster]
# (_extract pid=2302951) [24-07-25 15:12:26] Begin feature extraction on P095's data.
# (_extract pid=2302965) [24-07-25 15:12:51] Begin feature extraction on P096's data.
# (_extract pid=2302957) [24-07-25 15:13:03] Complete feature extraction on P077's data (140.17 s). [repeated 3x across cluster]
# (_extract pid=2302966) Element 246: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 654x across cluster]
# (_extract pid=2302966) [24-07-25 15:12:55] Begin feature extraction on P098's data. [repeated 2x across cluster]
# (_extract pid=2302960) [24-07-25 15:13:43] Complete feature extraction on P079's data (151.78 s).
# (_extract pid=2302957) Element 203: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 204x across cluster]
# (_extract pid=2302957) [24-07-25 15:13:03] Begin feature extraction on P099's data.
# (_extract pid=2302960) [24-07-25 15:13:43] Begin feature extraction on P101's data.
# (_extract pid=2302959) [24-07-25 15:14:02] Complete feature extraction on P088's data (120.12 s).
# (_extract pid=2302960) Element 214: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 215x across cluster]
# (_extract pid=2302959) [24-07-25 15:14:02] Begin feature extraction on P102's data.
# (_extract pid=2302964) [24-07-25 15:14:17] Complete feature extraction on P084's data (146.79 s). [repeated 3x across cluster]
# (_extract pid=2302954) Element 216: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 568x across cluster]
# (_extract pid=2302954) [24-07-25 15:14:04] Begin feature extraction on P104's data. [repeated 2x across cluster]
# (_extract pid=2302956) [24-07-25 15:14:27] Complete feature extraction on P097's data (92.31 s). [repeated 2x across cluster]
# (_extract pid=2302962) Element 195: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 401x across cluster]
# (_extract pid=2302962) [24-07-25 15:14:20] Begin feature extraction on P107's data. [repeated 2x across cluster]
# (_extract pid=2302955) [24-07-25 15:14:31] Complete feature extraction on P083's data (162.76 s). [repeated 2x across cluster]
# (_extract pid=2302955) Element 224: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 521x across cluster]
# (_extract pid=2302955) [24-07-25 15:14:32] Begin feature extraction on P110's data. [repeated 3x across cluster]
# (_extract pid=2302953) [24-07-25 15:14:56] Complete feature extraction on P092's data (154.04 s). [repeated 2x across cluster]
# (_extract pid=2302963) Element 201: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 202x across cluster]
# (_extract pid=2302963) [24-07-25 15:14:34] Begin feature extraction on P114's data.
# (_extract pid=2302953) [24-07-25 15:14:56] Begin feature extraction on P115's data.
# (_extract pid=2302951) [24-07-25 15:15:03] Complete feature extraction on P095's data (157.29 s).
# (_extract pid=2302953) Element 204: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 205x across cluster]
# (_extract pid=2302951) [24-07-25 15:15:04] Begin feature extraction on P116's data.
# (_extract pid=2302952) [24-07-25 15:15:04] Complete feature extraction on P094's data (159.43 s).
# (_extract pid=2302952) Element 205: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 411x across cluster]
# (_extract pid=2302952) [24-07-25 15:15:04] Begin feature extraction on P117's data.
# (_extract pid=2302965) [24-07-25 15:15:13] Complete feature extraction on P096's data (141.94 s).
# (_extract pid=2302965) [24-07-25 15:15:13] Begin feature extraction on P118's data.
# (_extract pid=2302966) [24-07-25 15:15:14] Complete feature extraction on P098's data (138.99 s).
# (_extract pid=2302966) Element 194: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 386x across cluster]
# (_extract pid=2302966) [24-07-25 15:15:15] Begin feature extraction on P119's data.
# (_extract pid=2302957) [24-07-25 15:15:30] Complete feature extraction on P099's data (146.33 s).
# (_extract pid=2302957) [24-07-25 15:15:30] Begin feature extraction on P120's data.
# (_extract pid=2302954) [24-07-25 15:15:39] Complete feature extraction on P104's data (94.31 s).
# (_extract pid=2302957) Element 210: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 211x across cluster]
# (_extract pid=2302954) [24-07-25 15:15:39] Begin feature extraction on P121's data.
# (_extract pid=2302960) [24-07-25 15:15:54] Complete feature extraction on P101's data (130.85 s).
# (_extract pid=2302954) Element 166: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 167x across cluster]
# (_extract pid=2302960) [24-07-25 15:15:54] Begin feature extraction on P122's data.
# (_extract pid=2302958) [24-07-25 15:16:15] Complete feature extraction on P109's data (107.80 s).
# (_extract pid=2302960) Element 159: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 160x across cluster]
# (_extract pid=2302958) [24-07-25 15:16:15] Begin feature extraction on P123's data.
# (_extract pid=2302959) [24-07-25 15:16:23] Complete feature extraction on P102's data (140.77 s).
# (_extract pid=2302958) Element 147: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 148x across cluster]
# (_extract pid=2302959) [24-07-25 15:16:24] Begin feature extraction on P124's data.
# (_extract pid=2302961) [24-07-25 15:16:46] Complete feature extraction on P103's data (162.78 s).
# (_extract pid=2302959) Element 227: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 228x across cluster]
# (_extract pid=2302961) [24-07-25 15:16:46] Begin feature extraction on P125's data.
# (_extract pid=2302963) [24-07-25 15:17:00] Complete feature extraction on P114's data (146.46 s).
# (_extract pid=2302961) Element 205: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 206x across cluster]
# (_extract pid=2302963) [24-07-25 15:17:01] Begin feature extraction on P126's data.
# (_extract pid=2302955) [24-07-25 15:17:06] Complete feature extraction on P110's data (154.08 s).
# (_extract pid=2302963) Element 203: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 204x across cluster]
# (_extract pid=2302955) [24-07-25 15:17:06] Begin feature extraction on P127's data.
# (_extract pid=2302953) [24-07-25 15:17:30] Complete feature extraction on P115's data (153.89 s). [repeated 2x across cluster]
# (_extract pid=2302965) Element 137: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 340x across cluster]
# (_extract pid=2302965) [24-07-25 15:17:09] Begin feature extraction on P131's data.
# (_extract pid=2302953) [24-07-25 15:17:31] Begin feature extraction on P133's data.
# (_extract pid=2302956) [24-07-25 15:17:35] Complete feature extraction on P108's data (188.61 s). [repeated 2x across cluster]
# (_extract pid=2302964) Element 224: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 439x across cluster]
# (_extract pid=2302964) [24-07-25 15:17:34] Begin feature extraction on P135's data.
# (_extract pid=2302962) [24-07-25 15:17:43] Complete feature extraction on P107's data (202.47 s).
# (_extract pid=2302956) Element 220: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 221x across cluster]
# (_extract pid=2302952) [24-07-25 15:17:44] Complete feature extraction on P117's data (159.52 s).
# (_extract pid=2302966) Element 194: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 650x across cluster]
# (_extract pid=2302951) [24-07-25 15:17:54] Complete feature extraction on P116's data (170.53 s). [repeated 2x across cluster]
# (_extract pid=2302951) Element 220: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 221x across cluster]
# (_extract pid=2302960) [24-07-25 15:18:09] Complete feature extraction on P122's data (134.34 s).
# (_extract pid=2302957) [24-07-25 15:18:09] Complete feature extraction on P120's data (159.04 s).
# (_extract pid=2302957) Element 218: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 417x across cluster]
# (_extract pid=2302954) [24-07-25 15:18:18] Complete feature extraction on P121's data (158.96 s).
# (_extract pid=2302958) [24-07-25 15:18:26] Complete feature extraction on P123's data (130.72 s).
# (_extract pid=2302954) Element 243: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 244x across cluster]
# (_extract pid=2302959) [24-07-25 15:18:36] Complete feature extraction on P124's data (132.10 s). [repeated 2x across cluster]
# (_extract pid=2302965) Element 130: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 332x across cluster]
# (_extract pid=2302963) [24-07-25 15:18:48] Complete feature extraction on P126's data (107.32 s).
# (_extract pid=2302959) Element 194: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 195x across cluster]
# (_extract pid=2302961) [24-07-25 15:18:50] Complete feature extraction on P125's data (123.37 s).
# (_extract pid=2302961) Element 215: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 442x across cluster]
# (_extract pid=2302964) [24-07-25 15:18:57] Complete feature extraction on P135's data (83.04 s). [repeated 2x across cluster]
# (_extract pid=2302964) Element 194: 0, Type: <class 'numpy.int64'>, Length: N/A [repeated 391x across cluster]
# (_extract pid=2302953) [24-07-25 15:19:02] Complete feature extraction on P133's data (91.24 s).
# (_extract pid=2302953) Element 202: 1, Type: <class 'numpy.int64'>, Length: N/A [repeated 203x across cluster]
