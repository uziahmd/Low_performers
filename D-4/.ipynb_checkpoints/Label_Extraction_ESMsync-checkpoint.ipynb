# %%
from Funcs.Utility import *
import numpy as np
import pandas as pd
from typing import Dict, Callable, Union, Tuple, List, Optional, Iterable
from datetime import timedelta as td
from scipy import stats
import ray
import warnings
import time
import ray
import dask

# %%
print(PATH_INTERMEDIATE)
# Out:
# /var/nfs_share/Overfitting/D-4/Intermediate

# %%
esm_path = os.path.join('Intermediate', 'EsmResponse.csv')

# %%
esm_df = pd.read_csv(esm_path)

# %%
esm_df
# Out:
#       pcode  intendedTriggerTime  actualTriggerTime   reactionTime  \
# 0      P001        1637718007000      1637718007012  1637718323396
# 1      P001        1637721522000      1637721522014  1637721539351
# 2      P001        1637726794000      1637726794012  1637727128306
# 3      P001        1637731738000      1637731738015  1637731765619
# 4      P001        1637735113000      1637735113010  1637735123563
# ...     ...                  ...                ...            ...
# 21833  P135        1641356523000      1641356523009  1641356541930
# 21834  P135        1641371411000      1641371412098  1641371431813
# 21835  P135        1641375915000      1641375915007  1641375924655
# 21836  P135        1641379289000      1641379290110  1641379323048
# 21837  P135        1641384187000      1641384187124  1641384282542
#
#         responseTime  happy  relaxed  cheerful  content  sad  anxious  \
# 0      1637718364764      4        4         4        5    2        1
# 1      1637721569541      4        4         4        5    0        0
# 2      1637727157539      6        5         6        6    0        0
# 3      1637731788862      4        4         3        4    1        1
# 4      1637735144845      5        6         4        5    1        0
# ...              ...    ...      ...       ...      ...  ...      ...
# 21833  1641356557520      5        6         6        4    0        0
# 21834  1641371448498      5        6         5        4    0        5
# 21835  1641375941705      5        6         4        0    0        2
# 21836  1641379344457      5        6         6        6    0        2
# 21837  1641384298624      4        6         4        5    0        0
#
#        depressed  angry  valence  arousal  stress  disturbance
# 0              1      1        1        1       1            2
# 1              0      0        1        1       2            1
# 2              0      0        3        3       0            6
# 3              1      0        1        1       2            3
# 4              0      0        2        1       1            3
# ...          ...    ...      ...      ...     ...          ...
# 21833          0      0        2       -3       5            6
# 21834          1      0        1       -3       4            6
# 21835          0      0        2       -3       4            4
# 21836          0      0        1       -3       2            5
# 21837          0      0        1       -3       3            4
#
# [21838 rows x 17 columns]

# %%
esm_df = esm_df[['pcode', 'responseTime', 'stress']]

# %%
esm_df
# Out:
#       pcode   responseTime  stress
# 0      P001  1637718364764       1
# 1      P001  1637721569541       2
# 2      P001  1637727157539       0
# 3      P001  1637731788862       2
# 4      P001  1637735144845       1
# ...     ...            ...     ...
# 21833  P135  1641356557520       5
# 21834  P135  1641371448498       4
# 21835  P135  1641375941705       4
# 21836  P135  1641379344457       2
# 21837  P135  1641384298624       3
#
# [21838 rows x 3 columns]

# %%
# Convert responseTime and stress to numeric, coerce errors to NaN
esm_df['responseTime'] = pd.to_numeric(esm_df['responseTime'], errors='coerce')
esm_df['stress'] = pd.to_numeric(esm_df['stress'], errors='coerce')

# Drop rows with NaN values
esm_df.dropna(subset=['responseTime', 'stress'], inplace=True)
# Out:
# /tmp/ipykernel_1900297/4055246896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   esm_df['responseTime'] = pd.to_numeric(esm_df['responseTime'], errors='coerce')
# /tmp/ipykernel_1900297/4055246896.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   esm_df['stress'] = pd.to_numeric(esm_df['stress'], errors='coerce')
# /tmp/ipykernel_1900297/4055246896.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   esm_df.dropna(subset=['responseTime', 'stress'], inplace=True)

# %%
print("NaN values per column:")
print(esm_df.isna().sum())
# Out:
# NaN values per column:
# pcode           0
# responseTime    0
# stress          0
# dtype: int64

# %%
# Check the unique values of responseTime and stress
print("Unique values in responseTime:", esm_df['responseTime'].unique())
print("Unique values in stress:", esm_df['stress'].unique())
# Out:
# Unique values in responseTime: [1637718364764 1637721569541 1637727157539 ... 1641375941705 1641379344457
#  1641384298624]
# Unique values in stress: [1 2 0 4 3 6 5]

# %%
esm_df.head()
# Out:
#   pcode   responseTime  stress
# 0  P001  1637718364764       1
# 1  P001  1637721569541       2
# 2  P001  1637727157539       0
# 3  P001  1637731788862       2
# 4  P001  1637735144845       1

# %%
print("Basic Statistics:")
print(esm_df.describe())
# Out:
# Basic Statistics:
#        responseTime       stress
# count  2.183800e+04  21838.00000
# mean   1.639389e+12      2.32851
# std    8.768959e+08      1.72344
# min    1.637717e+12      0.00000
# 25%    1.638704e+12      1.00000
# 50%    1.639368e+12      2.00000
# 75%    1.640001e+12      4.00000
# max    1.641905e+12      6.00000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(esm_df['responseTime'], bins=30)
plt.title('Distribution of Response Time')

plt.subplot(1, 2, 2)
plt.hist(esm_df['stress'], bins=30)
plt.title('Distribution of Stress')

plt.tight_layout()
plt.show()

# %%
def calculate_step_count(user_folder, response_time):
    step_file_path = os.path.join(user_folder, 'Fitbit-StepCount.csv')
    if not os.path.exists(step_file_path):
        print(f"File does not exist: {step_file_path}")
        return None

    steps_df = pd.read_csv(step_file_path)
    steps_df['timestamp'] = pd.to_numeric(steps_df['timestamp'], errors='coerce')
    steps_df['value'] = pd.to_numeric(steps_df['value'], errors='coerce')

    start_time = response_time - 30 * 60 * 1000  # 30 minutes before
    end_time = response_time + 30 * 60 * 1000   # 30 minutes after

    # Filter steps within the 1-hour window
    mask = (steps_df['timestamp'] >= start_time) & (steps_df['timestamp'] <= end_time)
    step_count = steps_df.loc[mask, 'value'].sum()

    print(f"User folder: {user_folder}, Response time: {response_time}, Step count: {step_count}")

    return step_count

# %%
step_counts = []
for index, row in esm_df.iterrows():
    user_folder = os.path.join(PATH_SENSOR, row['pcode'])
    response_time = row['responseTime']
    step_count = calculate_step_count(user_folder, response_time)
    step_counts.append(step_count)
# Out:
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637718364764, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637721569541, Step count: 867
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637727157539, Step count: 632
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637731788862, Step count: 291
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637735144845, Step count: 286
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637738679285, Step count: 62
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637741895183, Step count: 392
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637746467521, Step count: 43
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637749842040, Step count: 257
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637804762192, Step count: 1254
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637807978553, Step count: 987
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637813289227, Step count: 1022
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637818193319, Step count: 25
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637821723994, Step count: 98
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637825092136, Step count: 326
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637828270082, Step count: 645
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637836299935, Step count: 275
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637891391217, Step count: 1360
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637899634081, Step count: 448
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637911543946, Step count: 1078
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637919282683, Step count: 84
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637922649838, Step count: 40
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637977318483, Step count: 7
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637980920133, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637986039635, Step count: 770
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637990970515, Step count: 83
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1637997887623, Step count: 4
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638001128040, Step count: 229
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638067165456, Step count: 198
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638072417415, Step count: 998
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638077371133, Step count: 1974
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638080864216, Step count: 10
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638084270125, Step count: 1278
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638087616935, Step count: 30
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638095447967, Step count: 4
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638100690307, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638150074715, Step count: 42
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638158840981, Step count: 1546
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1638163794793, Step count: 370
# User folder: /var/nfs_share/D#4/newdata/P001, Response time: 1
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641125017949, Step count: 14
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641173891967, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641184065802, Step count: 1033
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641193572353, Step count: 19
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641199416997, Step count: 1421
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641203970703, Step count: 2491
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641206513820, Step count: 22
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641211413142, Step count: 333
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641260356443, Step count: 42
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641265240015, Step count: 117
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641270336155, Step count: 1409
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641275228543, Step count: 104
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641285058399, Step count: 1322
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641289559986, Step count: 2584
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641292915569, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641297811795, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641346999578, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641351636642, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641356557520, Step count: 944
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641371448498, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641375941705, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641379344457, Step count: 0
# User folder: /var/nfs_share/D#4/newdata/P135, Response time: 1641384298624, Step count: 0

# %%
esm_df['step_count'] = step_counts
# Out:
# /tmp/ipykernel_1900297/3049517787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   esm_df['step_count'] = step_counts

# %%
print(esm_df)
# Out:
#       pcode   responseTime  stress  step_count
# 0      P001  1637718364764       1           0
# 1      P001  1637721569541       2         867
# 2      P001  1637727157539       0         632
# 3      P001  1637731788862       2         291
# 4      P001  1637735144845       1         286
# ...     ...            ...     ...         ...
# 21833  P135  1641356557520       5         944
# 21834  P135  1641371448498       4           0
# 21835  P135  1641375941705       4           0
# 21836  P135  1641379344457       2           0
# 21837  P135  1641384298624       3           0
#
# [21838 rows x 4 columns]

# %%
def remove_first_last(df_grouped):
    return df_grouped.iloc[1:-1]

esm_df = esm_df.groupby('pcode').apply(remove_first_last).reset_index(drop=True)

# %%
esm_df = esm_df[['pcode', 'responseTime', 'stress', 'step_count']].copy()

# Convert the 'responseTime' column to datetime format without using .loc
esm_df['responseTime'] = pd.to_datetime(esm_df['responseTime'], unit='ms', utc=True).dt.tz_convert(DEFAULT_TZ)

# Display the DataFrame to verify the changes
print(esm_df.head())
# Out:
#   pcode                     responseTime  stress
# 0  P001 2021-11-24 11:39:29.541000+09:00       2
# 1  P001 2021-11-24 13:12:37.539000+09:00       0
# 2  P001 2021-11-24 14:29:48.862000+09:00       2
# 3  P001 2021-11-24 15:25:44.845000+09:00       1
# 4  P001 2021-11-24 16:24:39.285000+09:00       0

# %%
esm_df = esm_df.rename(columns={'responseTime': 'timestamp'})

# %%
esm_df
# Out:
#       pcode                        timestamp  stress
# 0      P001 2021-11-24 11:39:29.541000+09:00       2
# 1      P001 2021-11-24 13:12:37.539000+09:00       0
# 2      P001 2021-11-24 14:29:48.862000+09:00       2
# 3      P001 2021-11-24 15:25:44.845000+09:00       1
# 4      P001 2021-11-24 16:24:39.285000+09:00       0
# ...     ...                              ...     ...
# 21621  P135 2022-01-05 12:00:36.642000+09:00       5
# 21622  P135 2022-01-05 13:22:37.520000+09:00       5
# 21623  P135 2022-01-05 17:30:48.498000+09:00       4
# 21624  P135 2022-01-05 18:45:41.705000+09:00       4
# 21625  P135 2022-01-05 19:42:24.457000+09:00       2
#
# [21626 rows x 3 columns]

# %%
esm_df.to_csv('labels_1h_esmsyn.csv', index=False)

# %%
esm_path = os.path.join('Intermediate', 'labels_1h_esmsyn.csv')
df = pd.read_csv(esm_path)

# %%
df
# Out:
#       pcode      timestamp  stress  step_count
# 0      P001  1637721569541       2         867
# 1      P001  1637727157539       0         632
# 2      P001  1637731788862       2         291
# 3      P001  1637735144845       1         286
# 4      P001  1637738679285       0          62
# ...     ...            ...     ...         ...
# 21621  P135  1641351636642       5           0
# 21622  P135  1641356557520       5         944
# 21623  P135  1641371448498       4           0
# 21624  P135  1641375941705       4           0
# 21625  P135  1641379344457       2           0
#
# [21626 rows x 4 columns]

# %%
print("Basic Statistics:")
print(df.describe())
# Out:
# Basic Statistics:
#           timestamp        stress    step_count
# count  2.162600e+04  21626.000000  21626.000000
# mean   1.639388e+12      2.330990    532.986821
# std    8.709147e+08      1.724663    736.073440
# min    1.637717e+12      0.000000      0.000000
# 25%    1.638707e+12      1.000000     34.000000
# 50%    1.639368e+12      2.000000    214.000000
# 75%    1.639999e+12      4.000000    754.000000
# max    1.641900e+12      6.000000   8279.000000

# %%
# Convert responseTime to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms', utc=True).dt.tz_convert(DEFAULT_TZ)

# %%
# Simple Matplotlib histograms for distribution plots
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(df['stress'], bins=30)
plt.title('Distribution of Stress')

plt.subplot(1, 2, 2)
plt.hist(df['step_count'], bins=30)
plt.title('Distribution of Step Count')

plt.tight_layout()
plt.show()

# %%
zero_count = (df['step_count'] == 0).sum()
print(zero_count)

# %% [markdown]
# Binarization

# %%
# Calculate personal means
personal_means = df.groupby('pcode').mean()[['stress', 'step_count']]

# Calculate overall means
overall_mean_stress = df['stress'].mean()
overall_mean_steps = df['step_count'].mean()

print("Personal Means:")
print(personal_means.head())

print("Overall Mean Stress:", overall_mean_stress)
print("Overall Mean Steps:", overall_mean_steps)

# %%
# Function to binarize based on personal means
def binarize_personal(row, personal_means):
    pcode = row['pcode']
    personal_mean_stress = personal_means.loc[pcode, 'stress']
    personal_mean_steps = personal_means.loc[pcode, 'step_count']
    
    row['stress_binary_personal'] = 1 if row['stress'] > personal_mean_stress else 0
    row['step_count_binary_personal'] = 1 if row['step_count'] > personal_mean_steps else 0
    return row

# Binarize based on personal means
df = df.apply(binarize_personal, axis=1, personal_means=personal_means)

# Binarize based on overall means
df['stress_binary_overall'] = df['stress'].apply(lambda x: 1 if x > overall_mean_stress else 0)
df['step_count_binary_overall'] = df['step_count'].apply(lambda x: 1 if x > overall_mean_steps else 0)

# Display the updated DataFrame
print(df.head())

# %%
df

# %%
# EDA for Binarized Data

# Distribution plots for personal binarized data using Matplotlib
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(df['stress_binary_personal'], bins=2, edgecolor='k')
plt.title('Binarized Stress (Personal Mean)')

plt.subplot(1, 2, 2)
plt.hist(df['step_count_binary_personal'], bins=2, edgecolor='k')
plt.title('Binarized Step Count (Personal Mean)')

plt.tight_layout()
plt.show()

# Distribution plots for overall binarized data using Matplotlib
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(df['stress_binary_overall'], bins=2, edgecolor='k')
plt.title('Binarized Stress (Overall Mean)')

plt.subplot(1, 2, 2)
plt.hist(df['step_count_binary_overall'], bins=2, edgecolor='k')
plt.title('Binarized Step Count (Overall Mean)')

plt.tight_layout()
plt.show()

# Correlation analysis for binarized data
correlation_binarized = df[['stress_binary_personal', 'step_count_binary_personal',
                            'stress_binary_overall', 'step_count_binary_overall']].corr()
print("Correlation Matrix (Binarized Data):")
print(correlation_binarized)

# Heatmap for correlation matrix (binarized data) using Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_binarized, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix (Binarized Data)')
plt.show()

# %%
zero_count = (df['step_count_binary_personal'] == 0).sum()
print(zero_count)

# %%
zero_count = (df['step_count_binary_overall'] == 0).sum()
print(zero_count)
